# %%
pip install langchain

# %%
pip install openai

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# %%
# Install the langchain-community package
# %pip install langchain_openai

# %%
from langchain_openai import ChatOpenAI

# %%
llm = ChatOpenAI(
    model_name="gpt-3.5-turbo",  # or "gpt-4"
    temperature=0.7
)

# %%
response = llm.invoke("What is the meaning of life?")
print(response)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 response = llm.invoke("What is the meaning of life?")
#       2 print(response)
#
# File ~/langchain/.conda/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:284, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     273 def invoke(
#     274     self,
#     275     input: LanguageModelInput,
#    (...)
#     279     **kwargs: Any,
#     280 ) -> BaseMessage:
#     281     config = ensure_config(config)
#     282     return cast(
#     283         ChatGeneration,
# --> 284         self.generate_prompt(
#     285             [self._convert_input(input)],
#     286             stop=stop,
#     287             callbacks=config.get("callbacks"),
#     288             tags=config.get("tags"),
#     289             metadata=config.get("metadata"),
# ...

# %%
from langchain.prompts import PromptTemplate

# %%
prompt = PromptTemplate(
    input_variables= ['food'],
    template="What is the best food to eat for {food}?"
)
